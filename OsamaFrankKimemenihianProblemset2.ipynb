# %% [markdown]
# # Question 1

# %%
a=0

def b():
    global a
    a=c(a)
    
def c(a):
    return a+2

b()
b()
b()
a
# Out:
# 6

# %% [markdown]
# >>>b() will return a(0) + 2 = 2
# >>>b() will return a(2) + 2 = 4
# >>>b() will return a(4) + 2 = 6
# >>>a = 6

# %% [markdown]
# # Question 2

# %%
def fileLength(file_name):
    file = open(file_name)
    contents = file.read()
    file.close()
    print(len(contents))
    
fileLength('midterm.py')
fileLength('idterm.py')
# Out:
# 123
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-b8d0bd4af0b6> in <module>
#       6
#       7 fileLength('midterm.py')
# ----> 8 fileLength('idterm.py')
#
# <ipython-input-1-b8d0bd4af0b6> in fileLength(file_name)
#       1 def fileLength(file_name):
# ----> 2     file = open(file_name)
#       3     contents = file.read()
#       4     file.close()
#       5     print(len(contents))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'idterm.py'

# %%
def fileLength(file_name):
    try:
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))
    except FileNotFoundError:
        print('file not found')
#fileLength('midterm.py')

fileLength('idterm.py')
# Out:
# file not found

# %% [markdown]
# # Question 4

# %%
x = int(input('enter your integer '))
def collatz(x):
    print(x)
    if x>1:
        if x%2 == 0:
            x=x/2
            collatz(x)
        else:
            x=(3*x)+ 1
            collatz(x)
    
collatz(x)
# Out:
# enter your integer 1
# 1

# %%
x = int(input('enter your integer '))
def collatz(x):
    print(x)
    if x>1:
        if x%2 == 0:
            x=x/2
            collatz(x)
        else:
            x=(3*x)+ 1
            collatz(x)
    
collatz(x)
# Out:
# enter your integer 10
# 10
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0
# 1.0

# %% [markdown]
# # Question 5

# %%
n=int(input('Enter a non-negative integer '))
def binary(n):
    if n>1:
        binary(n//2)
    print(n%2, end = '')
               
binary(n)
# Out:
# Enter a non-negative integer 0
# 0

# %%
n=int(input('Enter a non-negative integer '))
def binary(n):
    if n>1:
        binary(n//2)
    print(n%2, end = '')
               
binary(n)
# Out:
# Enter a non-negative integer 1
# 1

# %%
n=int(input('Enter a non-negative integer '))
def binary(n):
    if n>1:
        binary(n//2)
    print(n%2, end = '')
               
binary(n)
# Out:
# Enter a non-negative integer 3
# 11

# %%
n=int(input('Enter a non-negative integer '))
def binary(n):
    if n>1:
        binary(n//2)
    print(n%2, end = '')
               
binary(n)
# Out:
# Enter a non-negative integer 9
# 1001

# %% [markdown]
# # Question 8

# %%
import sqlite3
conn=sqlite3.connect('Weather')
cur=conn.cursor()
cur.execute('CREATE TABLE Osama(city TEXT, country TEXT, season TEXT, temperature FLOAT, rainfall FLOAT)')
cur.execute("INSERT INTO Osama VALUES ('Mumbai','India', 'Winter', 24.8, 5.9)")
cur.execute("INSERT INTO Osama VALUES ('Mumbai','India', 'Spring', 28.4, 16.2)")
cur.execute("INSERT INTO Osama VALUES ('Mumbai','India', 'Summer', 27.9, 1549.4)")
cur.execute("INSERT INTO Osama VALUES ('Mumbai','India', 'Fall', 27.6, 346.0)")
cur.execute("INSERT INTO Osama VALUES ('London','United Kingdom', 'Winter', 4.2, 207.7)")
cur.execute("INSERT INTO Osama VALUES ('London','United Kingdom', 'Spring', 8.3, 169.6)")
cur.execute("INSERT INTO Osama VALUES ('London','United Kingdom', 'Summer', 15.7, 157.0)")
cur.execute("INSERT INTO Osama VALUES ('London','United Kingdom', 'Fall', 10.4, 218.5)")
cur.execute("INSERT INTO Osama VALUES ('Cairo','Egypt', 'Winter', 13.6, 16.5)")
cur.execute("INSERT INTO Osama VALUES ('Cairo','Egypt', 'Spring', 20.7, 6.5)")
cur.execute("INSERT INTO Osama VALUES ('Cairo','Egypt', 'Summer', 27.7, 0.1)")
cur.execute("INSERT INTO Osama VALUES ('Cairo','Egypt', 'Fall', 22.2, 4.5)")
conn.commit()

# %% [markdown]
# # 8a

# %%
print ('Temperatures:')
cur.execute('SELECT temperature FROM Osama')
cur.fetchall()
# Out:
# Temperatures:
# [(24.8,),
#  (28.4,),
#  (27.9,),
#  (27.6,),
#  (4.2,),
#  (8.3,),
#  (15.7,),
#  (10.4,),
#  (13.6,),
#  (20.7,),
#  (27.7,),
#  (22.2,)]

# %% [markdown]
# # 8b

# %%
print ('Cities:')
cur.execute('SELECT DISTINCT city FROM Osama')
cur.fetchall()
# Out:
# Cities:
# [('Mumbai',), ('London',), ('Cairo',)]

# %% [markdown]
# # 8c

# %%
print ('Records from India:')
cur.execute("SELECT * FROM Osama WHERE Country ='India'")
cur.fetchall()
# Out:
# Records from India:
# [('Mumbai', 'India', 'Winter', 24.8, 5.9),
#  ('Mumbai', 'India', 'Spring', 28.4, 16.2),
#  ('Mumbai', 'India', 'Summer', 27.9, 1549.4),
#  ('Mumbai', 'India', 'Fall', 27.6, 346.0)]

# %% [markdown]
# # 8d

# %%
print ('Fall records:')
cur.execute ("SELECT DISTINCT * FROM Osama WHERE season='Fall'")
cur.fetchall()
# Out:
# Fall records:
# [('Mumbai', 'India', 'Fall', 27.6, 346.0),
#  ('London', 'United Kingdom', 'Fall', 10.4, 218.5),
#  ('Cairo', 'Egypt', 'Fall', 22.2, 4.5)]

# %% [markdown]
# # 8e

# %%
print ('Average Rainfall between 200 and 400:')
cur.execute ("SELECT DISTINCT city,country, season FROM Osama WHERE rainfall BETWEEN 200 AND 400")
cur.fetchall()
# Out:
# Average Rainfall between 200 and 400:
# [('Mumbai', 'India', 'Fall'),
#  ('London', 'United Kingdom', 'Winter'),
#  ('London', 'United Kingdom', 'Fall')]

# %% [markdown]
# # 8f

# %%
print ('Fall temperature above 20:')
cur.execute ("SELECT DISTINCT city,country,Temperature FROM Osama WHERE Season='Fall' AND Temperature > 20")
cur.fetchall()
# Out:
# Fall temperature above 20:
# [('Mumbai', 'India', 27.6), ('Cairo', 'Egypt', 22.2)]

# %% [markdown]
# # 8g

# %%
print ('Sum rainfall Cairo')
cur.execute ("SELECT SUM(Rainfall) FROM Osama WHERE city='Cairo'")
cur.fetchall()
# Out:
# Sum rainfall Cairo
# [(27.6,)]

# %% [markdown]
# # 8h

# %%
print ('Sum rainfall all seasons')
cur.execute ("SELECT SUM(Rainfall) FROM Osama")
cur.fetchall()
# Out:
# Sum rainfall all seasons
# [(2697.8999999999996,)]

# %% [markdown]
# # Question 9

# %% [markdown]
# # 9a

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
newlist = [x.upper() for x in words]
print(newlist)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']

# %% [markdown]
# # 9b

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
newlist = [x.lower() for x in words]
print(newlist)
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %% [markdown]
# # 9c

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
newlist = [len(x) for x in words]
print(newlist)
# Out:
# [3, 5, 5, 3, 5, 4, 3, 4, 3]

# %% [markdown]
# # 9d

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
newlist = [x.upper() x.lower() len(x) for x in words]
print(newlist)
# Out:
#   File "<ipython-input-38-90d0de42d2ac>", line 2
#     newlist = [x.upper() x.lower() len(x) for x in words]
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 9e

# %%
words = ['The', 'Quick', 'Brown', 'Fox', 'Jumps', 'Over', 'The', 'Lazy', 'Dog']
newlist = [z for z in words if len(z)>3]
print(newlist)
# Out:
# ['Quick', 'Brown', 'Jumps', 'Over', 'Lazy']
